# %%
import pandas as pd

# %%
files = ['cian_flats_Белгород_all_rooms.csv',
         'cian_flats_Волгоград_all_rooms.csv', 
         'cian_flats_Воронеж_all_rooms.csv', 
         'cian_flats_Краснодар_all_rooms.csv', 
         'cian_flats_Красноярск_all_rooms.csv',
         'cian_flats_Курск_all_rooms.csv', 
         'cian_flats_Москва_all_rooms.csv', 
         'cian_flats_Санкт-Петербург_all_rooms.csv', 
         'cian_flats_Сочи_all_rooms.csv', 
         'cian_flats_Уфа_all_rooms.csv']

dfs = [pd.read_csv(f) for f in files]

pd.concat(dfs).to_csv('all_flats.csv', index=False)

# %%
df = pd.read_csv('all_flats.csv')

# %%
df
# Out:
#                   author        author_type  \
# 0           Трансюжстрой          developer
# 1      Самолет Плюс СОТА  real_estate_agent
# 2         Этажи Белгород  real_estate_agent
# 3           Трансюжстрой          developer
# 4      Самолет Плюс СОТА  real_estate_agent
# ...                  ...                ...
# 31011       ID 127760747            realtor
# 31012       ID 127755678            realtor
# 31013          ЭТАЖИ Уфа  real_estate_agent
# 31014          Новый дом  real_estate_agent
# 31015          ЭТАЖИ Уфа  real_estate_agent
#
#                                                  url  location deal_type  \
# 0      https://belgorod.cian.ru/sale/flat/308890403/  Белгород      sale
# 1      https://belgorod.cian.ru/sale/flat/298956208/  Белгород      sale
# 2      https://belgorod.cian.ru/sale/flat/314274946/  Белгород      sale
# 3      https://belgorod.cian.ru/sale/flat/294909807/  Белгород      sale
# ...

# %%
df['deal_type'].unique()
# Out:
# array(['sale'], dtype=object)
